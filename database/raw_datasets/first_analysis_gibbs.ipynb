# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd
import xarray as xr

# %% [markdown]
# # Start with Shoreline and Bluff edge

# %%
# Read the Shapefile into a GeoDataFrame
gdf_be = gpd.read_file('gibbs/BarterIsland_BluffEdge_1950to2020/BarterIsland_BluffEdge_1950to2020.shp')
gdf_sl = gpd.read_file('gibbs/BarterIsland_Shoreline_1947to2020/BarterIsland_Shoreline_1947to2020.shp')

# %%
gdf_be.head()
# Out:
#         Date_  Year_  UNCY       Feature  \
# 0  07/13/1979   1979   2.8  Top of bluff
# 1  07/13/1979   1979   2.8  Top of bluff
# 2  07/13/1979   1979   2.8  Top of bluff
# 3  09/19/2000   2000   3.3  Top of bluff
# 4  06/23/2008   2008   1.9  Top of bluff
#
#                                          Source  \
# 0              AHAP, Color infrared photography
# 1              AHAP, Color infrared photography
# 2              AHAP, Color infrared photography
# 3  Maxar IKONOS, Panchromatic satellite imagery
# 4    Maxar WV01, Panchromatic satellite imagery
#
#                                             geometry
# 0  LINESTRING (400255.969 7782934.452, 400255.649...
# 1  LINESTRING (398448.276 7783087.702, 398444.115...
# 2  LINESTRING (398096.909 7783042.987, 398088.178...
# 3  LINESTRING (398542.029 7783063.298, 398542.468...
# 4  LINESTRING (398549.900 7783054.206, 398551.227...

# %%
gdf_be.describe()
# Out:
#              Year_        UNCY
# count   491.000000  491.000000
# mean   2006.745418    1.291039
# std      17.654807    0.957953
# min    1950.000000    0.200000
# 25%    2008.000000    0.500000
# 50%    2013.000000    1.100000
# 75%    2016.000000    1.800000
# max    2020.000000    5.100000

# %%
len(gdf_be.Date_.unique())
# Out:
# 25

# %%
fig, ax = plt.subplots(figsize=(15, 5))

gdf_be.plot(ax=ax, color='black', alpha=0.2, label='bluff edges')
gdf_sl.plot(ax=ax, color='C1', alpha=0.1, label='shorelines')

ax.set_xlabel('x [m]')
ax.set_ylabel('y [m]')

plt.legend()

# %% [markdown]
# # Secondly, Shoreline and Bluff edge change rate

# %%
# Read the Shapefile into a GeoDataFrame
gdf_be_cr = gpd.read_file('gibbs/BarterIsland_BluffTransect_ChangeRates_1950to2020/BarterIsland_BluffTransect_ChangeRates_1950to2020.shp')
gdf_sl_cr = gpd.read_file('gibbs/BarterIsland_ShoreTransect_ChangeRates_1947to2020/BarterIsland_ShoreTransect_ChangeRates_1947to2020.shp')

# %%
gdf_be_cr.head()
# Out:
#    TransectID  BaselineID  GroupID  TransOrder  Azimuth  ShrCount    TCD  \
# 0           3           1        1           1   182.67        25  22.25
# 1           4           1        1           2   182.67        25  30.00
# 2           5           1        1           3   182.67        25  40.00
# 3           6           1        1           4   182.67        25  50.00
# 4           7           1        1           5   182.67        25  60.00
#
#    SHAPE_Leng    SCE    NSM  ...   LR2   LSE  LCI90   WLR   WR2   WSE  WCI90  \
# 0  299.795447  14.94 -14.94  ...  0.91  1.72   0.03 -0.13  0.52  1.45   0.05
# 1  300.000000  17.56 -17.56  ...  0.93  1.73   0.03 -0.15  0.53  1.62   0.05
# 2  300.000000  19.26 -19.26  ...  0.95  1.40   0.02 -0.15  0.52  1.59   0.05
# 3  300.000000  20.61 -20.60  ...  0.95  1.52   0.03 -0.14  0.47  1.69   0.05
# 4  300.000000  23.43 -23.43  ...  0.94  1.89   0.03 -0.19  0.54  1.93   0.06
#
#      Trans_Yrs                                    Calc_Yrs  \
# ...

# %%
gdf_be_cr.describe()
# Out:
#          TransectID  BaselineID  GroupID    TransOrder       Azimuth  \
# count  10675.000000     10675.0  10675.0  10675.000000  10675.000000
# mean     164.243747         1.0      1.0    162.243747    179.305341
# std       93.388260         0.0      0.0     93.388260      4.653289
# min        3.000000         1.0      1.0      1.000000    172.510000
# 25%       83.000000         1.0      1.0     81.000000    172.510000
# 50%      164.000000         1.0      1.0    162.000000    182.670000
# 75%      245.000000         1.0      1.0    243.000000    182.670000
# max      328.000000         1.0      1.0    326.000000    182.670000
#
#            ShrCount           TCD    SHAPE_Leng           SCE           NSM  \
# count  10675.000000  10675.000000  10675.000000  10675.000000  10675.000000
# mean       3.331616   1632.444426    299.999387     10.038538    -10.000535
# std        4.930718    933.870594      0.011183     22.889266     22.881358
# ...

# %%
len(gdf_be_cr.TransectID.unique())
# Out:
# 326

# %%
gdf_sl_cr.describe()
# Out:
#         TransectID   BaselineID      GroupID   TransOrder      Azimuth  \
# count  1902.000000  1902.000000  1902.000000  1902.000000  1902.000000
# mean    955.869085     2.062566     2.062566   958.410095   177.264642
# std     553.086449     1.061882     1.061882   554.383733    30.367089
# min       1.000000     1.000000     1.000000     2.000000   112.560000
# 25%     476.250000     1.000000     1.000000   477.250000   163.047500
# 50%     957.500000     2.000000     2.000000   957.500000   182.270000
# 75%    1434.750000     3.000000     3.000000  1439.750000   204.440000
# max    1914.000000     4.000000     4.000000  1915.000000   204.440000
#
#           ShrCount           TCD   SHAPE_Leng          SCE          NSM  \
# count  1902.000000   1902.000000  1902.000000  1902.000000  1902.000000
# mean      4.148265  10441.940478   893.096812 -2953.856872 -3139.856346
# std       2.772279  13808.883627   197.999696  4709.773082  4587.411000
# ...

# %%
len(gdf_sl_cr.TransectID.unique())
# Out:
# 1902

# %%
transect_id = 300

fig, ax = plt.subplots(figsize=(15, 5))

gdf_be.plot(ax=ax, color='C0', alpha=0.2)
gdf_sl.plot(ax=ax, color='C1', alpha=0.2)

gdf_be_cr[gdf_be_cr.TransectID==transect_id].plot(ax=ax, color='red')
gdf_sl_cr[gdf_sl_cr.TransectID==transect_id].plot(ax=ax, color='red')
# Out:
# <Axes: >

# %% [markdown]
# # Finally, Shoreline and Bluff edge baseline

# %%
# Read the Shapefile into a GeoDataFrame
gdf_be_bl = gpd.read_file('gibbs/BarterIsland_BluffEdgeBaseline/BarterIsland_BluffEdgeBaseline.shp')
gdf_sl_bl = gpd.read_file('gibbs/BarterIsland_ShorelineBaseline/BarterIsland_ShorelineBaseline.shp')

# %%
gdf_be_bl.head()
# Out:
#    ID   Shape_Leng                                           geometry
# 0   1  3276.912651  LINESTRING (400621.969 7783101.406, 398511.247...

# %%
gdf_be_bl.describe()
# Out:
#         ID   Shape_Leng
# count  1.0     1.000000
# mean   1.0  3276.912651
# std    NaN          NaN
# min    1.0  3276.912651
# 25%    1.0  3276.912651
# 50%    1.0  3276.912651
# 75%    1.0  3276.912651
# max    1.0  3276.912651

# %%
gdf_sl_bl.describe()
# Out:
#        OBJECTID        ID  DSAS_searc   Shape_Leng
# count  4.000000  4.000000     4.00000     4.000000
# mean   2.500000  2.500000   950.00000  4785.716160
# std    1.290994  1.290994   420.31734  4079.044663
# min    1.000000  1.000000   500.00000  1255.014455
# 25%    1.750000  1.750000   725.00000  1299.852158
# 50%    2.500000  2.500000   900.00000  4466.867749
# 75%    3.250000  3.250000  1125.00000  7952.731751
# max    4.000000  4.000000  1500.00000  8954.114687

# %%
fig, ax = plt.subplots(figsize=(15, 5))

gdf_be.plot(ax=ax, color='C0', alpha=0.2)
gdf_sl.plot(ax=ax, color='C1', alpha=0.2)

gdf_be_bl.plot(ax=ax, color='red')
gdf_sl_bl.plot(ax=ax, color='black')
# Out:
# <Axes: >
