# %%
import os
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

from datetime import datetime

# %%
save_path = Path("C:/Users/bruij_kn/OneDrive - Stichting Deltares/Documents/GitHub/msc-thesis/Figures/Python")

# %%
parent = os.path.join(Path(os.getcwd()).parent)

sys.path.append(parent)

from utils.bathymetry import generate_schematized_bathymetry

# %%
SMALL_SIZE = 16
MEDIUM_SIZE = 20
BIGGER_SIZE = 25

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
df_be = gpd.read_file(Path("ts_datasets/bluff_edges.csv"))
sort_mask = np.argsort(df_be.time.values)
df_be = df_be.iloc[sort_mask]

df_be['time'] = pd.to_datetime(df_be.time.values)
df_be['distance_from_ref'] = np.float32(df_be['distance_from_ref'].values)

df_sl = gpd.read_file(Path("ts_datasets/shore_lines.csv"))
sort_mask = np.argsort(df_sl.time.values)
df_sl = df_sl.iloc[sort_mask]

df_sl['time'] = pd.to_datetime(df_sl.time.values)
df_sl['distance_from_ref'] = np.float32(df_sl['distance_from_ref'].values)


df_be.head()
# Out:
#    field_1       time  distance_from_ref transect_id  \
# 3        3 1950-08-02          43.059185       134.0
# 2        2 1955-07-24          55.670830       134.0
# 4        4 1969-07-25          84.629684       134.0
# 11      11 1975-07-07          93.130219       134.0
# 6        6 1979-07-13          93.873360       134.0
#
#                                             ref_point  \
# 3   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 2   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 4   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 11  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 6   0    POINT (399293.416 7783163.429)\ndtype: ge...
#
#                                          geometry
# 3   POINT (-143.65624731604254 70.13496685853804)
# 2   POINT (-143.65624832870435 70.13485378355169)
# 4     POINT (-143.656250653975 70.13459414082698)
# 11  POINT (-143.65625133653052 70.13451792571242)
# 6   POINT (-143.65625139620138 70.13451126277761)

# %%
display(df_be)
# Out:
#    field_1       time  distance_from_ref transect_id  \
# 3        3 1950-08-02          43.059185       134.0
# 2        2 1955-07-24          55.670830       134.0
# 4        4 1969-07-25          84.629684       134.0
# 11      11 1975-07-07          93.130219       134.0
# 6        6 1979-07-13          93.873360       134.0
# 0        0 2000-09-19         146.639771       134.0
# 5        5 2004-09-18         154.219727       134.0
# 8        8 2006-07-13         154.864197       134.0
# 7        7 2007-07-04         155.431427       134.0
# 1        1 2008-06-23         158.579712       134.0
# 9        9 2008-09-19         160.587845       134.0
# 10      10 2009-08-02         162.015076       134.0
# 13      13 2010-07-25         162.064453       134.0
# 14      14 2010-09-06         162.469925       134.0
# 12      12 2011-07-15         162.406830       134.0
# 21      21 2012-07-11         164.520844       134.0
# 23      23 2013-08-07         178.177261       134.0
# 20      20 2014-07-01         178.445206       134.0
# 18      18 2014-09-07         178.921814       134.0
# 19      19 2015-07-05         179.482483       134.0
# 22      22 2016-08-27         187.251617       134.0
# 17      17 2017-07-13         189.897736       134.0
# 16      16 2018-07-30         195.175919       134.0
# 15      15 2019-09-05         199.375015       134.0
# 24      24 2020-07-10         200.678741       134.0
#
#                                             ref_point  \
# 3   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 2   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 4   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 11  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 6   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 0   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 5   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 8   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 7   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 1   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 9   0    POINT (399293.416 7783163.429)\ndtype: ge...
# 10  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 13  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 14  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 12  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 21  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 23  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 20  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 18  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 19  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 22  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 17  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 16  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 15  0    POINT (399293.416 7783163.429)\ndtype: ge...
# 24  0    POINT (399293.416 7783163.429)\ndtype: ge...
#
#                                          geometry
# 3   POINT (-143.65624731604254 70.13496685853804)
# 2   POINT (-143.65624832870435 70.13485378355169)
# 4     POINT (-143.656250653975 70.13459414082698)
# 11  POINT (-143.65625133653052 70.13451792571242)
# 6   POINT (-143.65625139620138 70.13451126277761)
# 0    POINT (-143.6562556331044 70.13403816333953)
# 5   POINT (-143.65625624173956 70.13397020203217)
# 8    POINT (-143.6562562934868 70.13396442384328)
# 7   POINT (-143.65625633903304 70.13395933806434)
# 1   POINT (-143.65625659182533 70.13393111080923)
# 9    POINT (-143.65625675306896 70.1339131060423)
# 10  POINT (-143.65625686766955 70.13390030952249)
# 13  POINT (-143.65625687163427 70.13389986681473)
# 14  POINT (-143.65625690419162 70.13389623139989)
# 12  POINT (-143.65625689912505 70.13389679714257)
# 21  POINT (-143.65625706887022 70.13387784307659)
# 23    POINT (-143.65625816541592 70.133755400646)
# 20  POINT (-143.65625818692993 70.13375299834946)
# 18    POINT (-143.6562582251999 70.1337487250468)
# 19  POINT (-143.65625827021825 70.13374369820875)
# 22  POINT (-143.65625889404188 70.13367404079648)
# 17   POINT (-143.6562591065122 70.13365031592342)
# 16   POINT (-143.6562595303251 70.13360299209333)
# 15   POINT (-143.6562598674925 70.13356534326418)
# 24  POINT (-143.65625997217492 70.13355365420492)

# %%
fig, ax = plt.subplots(figsize=(15,5))

# print(df_be.time.values)
# print(df_be.distance_from_ref.values)

ax.plot(df_be.time.values, df_be.distance_from_ref.values)
ax.plot(df_sl.time.values, df_sl.distance_from_ref.values)

# %%
def get_rates_and_plot_dates(df):

    def difference_in_years(date1, date2):
        
        date1 = pd.to_datetime(date1)
        date2 = pd.to_datetime(date2)
        
        # difference_in_days = (date2_dt - date1_dt).days
        
        difference_in_days = (date2 - date1).days

        difference_in_years = difference_in_days / 365.25
        
        return difference_in_years

    dx = df['distance_from_ref'].values[1:] - df['distance_from_ref'].values[:-1]
    dt = np.zeros(dx.shape)

    for i, date1, date2 in zip(np.arange(len(df)), df.time.values[:-1], df.time.values[1:]):
        
        dt[i] = difference_in_years(date1, date2)
    
    dx_dt2 = np.repeat(dx/dt, 2)

    t2 = np.repeat(df.time.values, 2)
    
    t2[1::2] += pd.to_timedelta(1, 's')
    
    t2 = t2[1:-1]
    
    return (t2, dx_dt2)

be_t2, be_dx_dt2 = get_rates_and_plot_dates(df_be)
sl_t2, sl_dx_dt2 = get_rates_and_plot_dates(df_sl)

# %%
# print(be_dx_dt2)
# print(be_t2)

# print(be_dx_dt2.shape)
# print(be_t2.shape)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots(figsize=(15,6))

ax.fill_between([pd.Timestamp('2009-08-02'), pd.Timestamp('2011-07-15')], 0, 200, alpha=0.3, label='low erosion', color='C2')
ax.fill_between([pd.Timestamp('2012-07-11'), pd.Timestamp('2015-07-05')], 0, 200, alpha=0.3, label='high erosion', color='C3')
ax.fill_between([pd.Timestamp('2016-08-27'), pd.Timestamp('2018-07-30')], 0, 200, alpha=0.3, label='high and low erosion', color='C4')


ax.plot(df_be.time.values, df_be.distance_from_ref.values, label='bluff edge', color='k')
ax.plot(df_sl.time.values, df_sl.distance_from_ref.values, label='shore line', color='r')

ax.scatter(df_be.time.values, df_be.distance_from_ref.values, color='k')
ax.scatter(df_sl.time.values, df_sl.distance_from_ref.values, color='r')

ax.set_xlim((pd.Timestamp('2000-01-01'), pd.Timestamp('2020-01-01')))
ax.set_ylim((120, 200))

ax.grid()

ax.set_xlabel('time')
ax.set_ylabel('distance from reference [m]')

ax.set_title('Historic shore line and bluff edge location, with validation periods')

ax.legend(loc='upper left')

fig.tight_layout()

fig.show()

figname = 'model_validation_periods_a.png'

fig.savefig(os.path.join(save_path, figname), bbox_inches='tight', facecolor='white', transparent=False)
# Out:
# C:\Users\bruij_kn\AppData\Local\Temp\ipykernel_29060\2328133423.py:28: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(15,6)
                       )
ax.axhline(0, color='k')

ax.fill_between([pd.Timestamp('2009-08-02'), pd.Timestamp('2011-07-15')], -200, 200, alpha=0.3, label='low erosion', color='C2')
ax.fill_between([pd.Timestamp('2012-07-11'), pd.Timestamp('2015-07-05')], -200, 200, alpha=0.3, label='high erosion', color='C3')
ax.fill_between([pd.Timestamp('2016-08-27'), pd.Timestamp('2018-07-30')], -200, 200, alpha=0.3, label='high and low erosion', color='C4')


ax.plot(be_t2, be_dx_dt2, label='bluff edge', color='r')
ax.plot(sl_t2, sl_dx_dt2, label='shore line', color='k')

ax.scatter(be_t2, be_dx_dt2, color='C0')
ax.scatter(sl_t2, sl_dx_dt2, color='C1')

ax.set_xlim((pd.Timestamp('2000-01-01'), pd.Timestamp('2020-01-01')))
ax.set_ylim((-6, 16))


ax.grid()

ax.set_xlabel('time')
ax.set_ylabel('averaged erosion rate [m/year]')

ax.set_title('Historic shore line and bluff edge retreat rates, with validation periods')

ax.legend(loc='upper left')

fig.tight_layout()

fig.show()

figname = 'model_validation_periods_b.png'

fig.savefig(os.path.join(save_path, figname), bbox_inches='tight', facecolor='white', transparent=False)
# Out:
# C:\Users\bruij_kn\AppData\Local\Temp\ipykernel_29060\3685045995.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
