# %%
import os

import numpy as np
import matplotlib.pyplot as plt

# %%
xb_times = np.loadtxt('xbeach_times.txt')

# %%
fig, ax = plt.subplots(figsize=(15, 3))

ax.plot(np.arange(len(xb_times)), xb_times)
