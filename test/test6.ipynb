# %%
import os

import numpy as np
import matplotlib.pyplot as plt

# %%
lon_min = 180 + (180 - 145)
lon_max = 180 + (180 - 140)

print(lon_min)
print(lon_max)
# Out:
# 215
# 220

# %%
xgr = np.loadtxt("x.grd")
zgr = np.loadtxt("bed.dep")

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.plot(xgr, zgr)
ax.scatter(xgr, zgr, color='r')

ax.axhline(0, -400, 600, color='k')

ax.grid()

# ax.set_xlim(-185, -125)

# ax.set_aspect("equal")
