# %%
import os
from pathlib import Path
import sys

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import xarray as xr

from matplotlib import colormaps
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable

# %%
parent = os.path.join(Path(os.getcwd()).parent)

print(parent)

sys.path.append(parent)
# Out:
# c:\Users\bruij_kn\OneDrive - Stichting Deltares\Documents\GitHub\thermo-morphological-model\test

# %%
SMALL_SIZE = 16
MEDIUM_SIZE = 20
BIGGER_SIZE = 25

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
fpath = Path("p:/11210070-usgscoop-202324-arcticxb/runs")

# %%
runid = 'sa_base'
ds_base_start = xr.load_dataset(os.path.join(fpath, runid + '/' + '0000000000.nc'))
ds_base_end = xr.load_dataset(os.path.join(fpath, runid + '/' + '0000017508.nc'))

runid1 = 'sa_lvl1_39'
ds1_start = xr.load_dataset(os.path.join(fpath, runid1 + '/' + '0000000000.nc'))
ds1_end = xr.load_dataset(os.path.join(fpath, runid1 + '/' + '0000017508.nc'))

runid2 = 'sa_lvl1_40'
ds2_start = xr.load_dataset(os.path.join(fpath, runid2 + '/' + '0000000000.nc'))
ds2_end = xr.load_dataset(os.path.join(fpath, runid2 + '/' + '0000017508.nc'))

# %%
fig, ax = plt.subplots(3, 1, figsize=(15,10))

ax[0].plot(ds_base_start.xgr, ds_base_start.zgr, label='sa_base (start)')
ax[0].plot(ds_base_end.xgr, ds_base_end.zgr, label='sa_base (end)')

ax[1].plot(ds1_start.xgr, ds1_start.zgr, label=f'{runid1} (start)')
ax[1].plot(ds1_end.xgr, ds1_end.zgr, label=f'{runid1} (end)')

ax[2].plot(ds2_start.xgr, ds2_start.zgr, label=f'{runid2} (start)')
ax[2].plot(ds2_end.xgr, ds2_end.zgr, label=f'{runid2} (end)')

for a in ax:
    pass
    # a.set_xlim((1460, 1480))
    # a.set_xlim((-20, 0))

# %%
fig, ax = plt.subplots(figsize=(15,10))

ax.plot(ds_base_start.xgr, ds_base_start.zgr, label='sa_base (start)')
ax.plot(ds_base_end.xgr, ds_base_end.zgr, label='sa_base (end)')

# ax.plot(ds1_start.xgr, ds1_start.zgr, label=f'{runid1} (start)')
ax.plot(ds1_end.xgr, ds1_end.zgr, label=f'{runid1} (end)')

# ax.plot(ds2_start.xgr, ds2_start.zgr, label=f'{runid2} (start)')
ax.plot(ds2_end.xgr, ds2_end.zgr, label=f'{runid2} (end)')

# ax.set_xlim((1460, 1480))
# ax.set_xlim((-20, 0))
# ax.set_xlim((1330, 1350))

ax.axhline(0, color='k', ls='--')

ax.legend()

# %%
fp = Path("P:/11210070-usgscoop-202324-arcticxb/runs/")

base_xb_runs = sum(np.loadtxt(os.path.join(fp, "sa_base/", "xbeach_times.txt")) > 0)
lvl1_39_xb_runs = sum(np.loadtxt(os.path.join(fp, "sa_lvl1_39/", "xbeach_times.txt")) > 0)
lvl1_40_xb_runs = sum(np.loadtxt(os.path.join(fp, "sa_lvl1_40/", "xbeach_times.txt")) > 0)

# %%
print(base_xb_runs)
print(lvl1_39_xb_runs)
print(lvl1_40_xb_runs)
# Out:
# 293
# 286
# 326

# %%
runid = 'sa_base'
ds_base_start = xr.load_dataset(os.path.join(fpath, runid + '/' + '0000000000.nc'))
ds_base_end = xr.load_dataset(os.path.join(fpath, runid + '/' + '0000017508.nc'))

runid1 = 'sa_lvl1_18'
ds1_start = xr.load_dataset(os.path.join(fpath, runid1 + '/' + '0000000000.nc'))
ds1_end = xr.load_dataset(os.path.join(fpath, runid1 + '/' + '0000017508.nc'))

# %%
fig, ax = plt.subplots(1, figsize=(15,15))

dz = 0

ax.plot(ds_base_start.xgr, ds_base_start.zgr+0.05, label='base start', color='r', marker='o')
ax.plot(ds_base_end.xgr, ds_base_end.zgr+2*dz, label='base end',color='y', marker='o')

ax.plot(ds1_start.xgr - 80, ds1_start.zgr+4*dz, label='ds1 start', color='g', marker='o')
ax.plot(ds1_end.xgr -80, ds1_end.zgr+6*dz, label='ds2 end', color='b', marker='o')

ax.legend()

# ax[0].set_xlim(1470, 1480)
# ax[1].set_xlim(1550, 1565)

# ax[0].set_xlim(-20, 0)

ax.axhline(0, ls='--', color= 'k')
# ax[1].set_xlim(-20, 0)

ax.set_xlim(1300, 1400)

ax.grid()

# %%
fp = Path("P:/11210070-usgscoop-202324-arcticxb/runs/")

base_xb_runs = sum(np.loadtxt(os.path.join(fp, "sa_base/", "xbeach_times.txt")) > 0)
lvl1_18_xb_runs = sum(np.loadtxt(os.path.join(fp, "sa_lvl1_18/", "xbeach_times.txt")) > 0)

# %%
print(base_xb_runs)
print(lvl1_18_xb_runs)
# Out:
# 293
# 294
